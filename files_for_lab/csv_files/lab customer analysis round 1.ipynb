# %%
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np   # numerical data

# %%
file1 = pd.read_csv('file1.csv') # pd.read means it is a panda function, reads it, and shows result in a data frame
display(file1.head(10)) # command to show the first 10 rows of the data frame
file1.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
file2 = pd.read_csv('file2.csv') # pd.read means it is a panda function, reads it, and shows result in a data frame
display(file2.head(10)) # command to show the first 10 rows of the data frame
file2.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
file3 = pd.read_csv('file3.csv') # pd.read means it is a panda function, reads it, and shows result in a data frame
display(file3.head(10)) # command to show the first 10 rows of the data frame
file3.shape
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
file3 = file3.rename(columns={'State':'ST',
                            'Gender':'GENDER', 
                            })
display(file3)
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file2[['Customer','ST','GENDER','Education','Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Policy Type','Vehicle Class','Total Claim Amount']
    ]
file3[['Customer','ST','GENDER','Education','Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Policy Type','Vehicle Class','Total Claim Amount']
    ]
# Out:
#      Customer          ST GENDER             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
data = pd.concat([file1, file2,file3], axis=0) # concat: built in panda function to concatenate . Axis = 0 means by rows, whilst 1 means by columns
data.shape
data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.pop('Education')
data.pop('Number of Open Complaints')
data
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.dtypes
# Out:
# Customer                    object
# ST                          object
# GENDER                      object
# Customer Lifetime Value     object
# Income                     float64
# Monthly Premium Auto       float64
# Policy Type                 object
# Vehicle Class               object
# Total Claim Amount         float64
# dtype: object
